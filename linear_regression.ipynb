# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df=pd.read_pickle("./dataframe/df_only_risky_events.pkl")
df.reset_index(inplace=True)
df.drop(['index'], inplace=True, axis=1)

# %%
df.head()
# Out:
#    __time_to_tca  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  \
# 0       0.832257         2244.0         11172.0                 87.9
# 1       0.580855          966.0           212.0                191.0
# 2       0.189825         1102.0           212.0                193.3
# 3       0.994637          456.0         11707.0                -22.1
# 4       0.759012          629.0         11707.0                -18.7
#
#    RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  \
# 0              -1474.9               1689.9               -201.4
# 1               -944.8                -68.9                 33.8
# 2              -1083.1                -75.0                 33.9
# 3                288.8                353.3                -10.2
# 4                395.3                489.9                -10.3
#
#    RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  ...  \
# 0              -8424.3              -7336.0               -3.418392  ...
# 1                 -8.4                209.3               -3.711974  ...
# 2                 -8.4                209.3               -3.913996  ...
# 3              -9077.7               7392.6               -2.055073  ...
# 4              -9077.7               7392.6               -2.649558  ...
#
#    PC_mavg_1  PC_trend_1  PC_trend_3  PC_gradient_1  PC_gradient_3  \
# 0  -3.475175    0.132439    0.590914       0.354472       0.579354
# 1  -3.981494    0.310256    0.575376       0.747481       0.536846
# 2  -3.882734   -0.202022    0.296282      -0.516640       0.270366
# 3  -2.841298    1.280567    1.312874       3.634346       1.445698
# 4  -2.680091   -0.594485    0.483623      -2.523011       0.486607
#
#      MD_mavg_1  MD_trend_1  MD_trend_3  MD_gradient_1  MD_gradient_3
# 0  2181.333333        47.0        17.0     125.795356      16.667421
# 1  1131.000000      -201.0      -326.0    -484.256505    -304.169574
# 2  1078.333333       136.0      -158.0     347.799165    -144.179478
# 3   709.666667      -577.0       124.0   -1637.570088     136.545083
# 4   706.000000       173.0       -11.0     734.217036     -11.067877
#
# [5 rows x 86 columns]

# %%
Y_df = df["COLLISSION_PROBABILITY"]
X_df= df.drop(["COLLISSION_PROBABILITY"], axis=1)

# %%
x, y = np.array(X_df), np.array(Y_df)

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.7464809303179271
# intercept: 27.408908062417066
# slope: [-1.41069045e-01 -3.04208241e-04  8.05201526e-05 -5.43656854e-05
#   1.23901209e-05 -7.58511866e-06 -1.36826545e-04  7.86152346e-05
#   1.47647776e-05 -5.53759298e-02  3.31585478e-04 -1.17176143e-02
#  -3.08253519e+02  5.24651146e+04 -3.00508917e+03  1.84596188e-01
#  -1.33537670e-01  1.00599650e-03 -1.08383248e-03  2.37863885e-03
#   5.79899720e-01  1.47223387e+03  6.30279307e+00  2.30321866e+00
#  -3.91830859e-03  6.45399895e-03 -3.15130054e-02 -2.29729031e-07
#  -5.29893907e-11 -1.81523029e-07 -2.04302841e-05  1.58636466e-01
#  -7.49726471e-02 -7.16958009e-03 -1.44795933e-04  8.90990284e-03
#  -9.82773244e-03  1.05296002e-03 -4.31838324e-02 -7.73773403e+00
#  -1.54643203e-02 -4.34767924e-02  1.45990271e-07 -6.70410191e-04
#  -6.25464638e-04  1.98391343e+01  3.63857731e+01 -2.10054843e+00
#   2.14850951e+01 -1.69752831e+00 -2.08555619e+00  3.45201002e+01
#   1.99110612e+01  3.58613612e+01  2.14683579e+01 -5.93809854e+00
#  -1.66853892e+00 -2.34100177e-01 -1.94479274e+00 -6.14587117e+00
#   3.00691061e+00  1.28396315e+00  3.95174369e-01  3.18128988e+00
#  -4.24189154e+00  3.76382370e-01  4.86542165e-01  2.06083252e+00
#   1.26228679e+00  2.27999126e+00 -5.12759616e-01  1.38825384e-01
#  -8.44659145e-02  2.29918901e-01 -5.18555113e-01  4.91196727e-01
#   5.09503617e-01  1.86667151e-01 -9.01954983e-02 -8.59404561e-02
#   2.94631739e-04  5.85188627e-05 -3.84887444e-05  3.81858990e-06
#   1.14515875e-04]

# %%
import pandas as pd
import datetime as dt
#from datetime import datetime, timedelta
import numpy as np
import os
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
from preparing_data import *

# %%
df=pd.read_csv("./data/train_data.csv")

# %%
cdm=convertKelvinDatasetToCDMFormat(df)

# %%
type(cdm)
# Out:
# pandas.core.frame.DataFrame

# %%
cdm.head()
# Out:
#    event_id                         TCA               CREATION_DATE  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  OBJECT1_CR_R  OBJECT1_CT_R  OBJECT1_CT_T  OBJECT1_CN_R  OBJECT1_CN_T  OBJECT1_CN_N  OBJECT1_CRDOT_R  OBJECT1_CRDOT_T  OBJECT1_CRDOT_N  OBJECT1_CRDOT_RDOT  OBJECT1_CTDOT_R  OBJECT1_CTDOT_T  OBJECT1_CTDOT_N  OBJECT1_CTDOT_RDOT  OBJECT1_CTDOT_TDOT  OBJECT1_CNDOT_R  OBJECT1_CNDOT_T  OBJECT1_CNDOT_N  OBJECT1_CNDOT_RDOT  OBJECT1_CNDOT_TDOT  OBJECT1_CNDOT_NDOT  OBJECT1_RECOMMENDED_OD_SPAN  OBJECT1_ACTUAL_OD_SPAN  OBJECT1_OBS_AVAILABLE  OBJECT1_OBS_USED  OBJECT1_RESIDUALS_ACCEPTED  OBJECT1_WEIGHTED_RMS  OBJECT1_SEDR   OBJECT1_TIME_LASTOB_START     OBJECT1_TIME_LASTOB_END  OBJECT1_CD_AREA_OVER_MASS  OBJECT1_CR_AREA_OVER_MASS  OBJECT1_APOGEE_ALTITUDE  OBJECT1_PERIGEE_ALTITUDE  OBJECT1_INCLINATION  OBJECT2_CR_R  OBJECT2_CT_R  OBJECT2_CT_T  \
# 0         0  2021-09-12T00:20:22.139175  2021-09-10T10:44:10.765584        14923.0         13792.0                453.8               5976.6             -13666.8                 -7.2             -12637.0              -5525.9            6.238000e-11     16.466810   -222.242200    18938.4700      2.112694     10.002140      3.173451         0.235719       -20.271280        -0.010106            0.021712        -0.016291         0.120850        -0.002307           -0.000127            0.000017         0.002069        -0.000637         0.002828        9.316645e-07           -0.000002            0.000009                         3.78                    3.78                    459               458                        98.9                 1.265      0.000051  2021-09-09T10:44:10.765584  2021-09-09T10:44:10.765584                   0.013826                   0.007173               646.745439                590.818294            97.806412      71140.79   -11961160.0  2.955756e+09
# 1         0  2021-09-12T00:20:22.139175  2021-09-10T19:21:34.693565        14544.0         13792.0                474.3               5821.2             -13319.8                 -7.0             -12637.0              -5525.9            4.408000e-11     12.438180    -14.462720     3143.8580      1.888744      6.113387      3.243452         0.014658        -3.339774        -0.005643            0.003561        -0.013159        -0.006237        -0.002043            0.000008            0.000014         0.001859         0.000255         0.002964       -9.040335e-07           -0.000002            0.000009                         3.79                    3.79                    456               455                        98.5                 1.270      0.000060  2021-09-09T19:21:34.693565  2021-09-09T19:21:34.693565                   0.013487                   0.009139               646.743506                590.823004            97.806420      68744.55   -11602080.0  2.924870e+09
# %%
cdm=convertTimestringToTimedate(cdm)

# %%
cdm=convertTimedateToDaysRange(cdm)

# %%
cdm.OBJECT1_TIME_LASTOB_START.value_counts()
# Out:
# 1.0      162495
# 2.0         103
# 180.0        25
# Name: OBJECT1_TIME_LASTOB_START, dtype: int64

# %%
df.t_time_lastob_start.value_counts()
# Out:
# 1.0      162506
# 2.0         103
# 180.0        25
# Name: t_time_lastob_start, dtype: int64

# %%
cdm.OBJECT1_TIME_LASTOB_END.value_counts()
# Out:
# 1.0      162495
# 2.0         103
# 180.0        25
# Name: OBJECT1_TIME_LASTOB_END, dtype: int64

# %%
df.t_time_lastob_end.value_counts()
# Out:
# 0.0    162506
# 1.0       103
# 2.0        25
# Name: t_time_lastob_end, dtype: int64

# %%
cdm.OBJECT2_TIME_LASTOB_START.value_counts()
# Out:
# 1.0      102159
# 180.0     35429
# 2.0       25035
# Name: OBJECT2_TIME_LASTOB_START, dtype: int64

# %%
df.c_time_lastob_start.value_counts()
# Out:
# 1.0      102159
# 180.0     35429
# 2.0       25035
# Name: c_time_lastob_start, dtype: int64

# %%
cdm.OBJECT2_TIME_LASTOB_END.value_counts()
# Out:
# 1.0      102159
# 180.0     35429
# 2.0       25035
# Name: OBJECT2_TIME_LASTOB_END, dtype: int64

# %%
df.c_time_lastob_end.value_counts()
# Out:
# 0.0    102159
# 2.0     35429
# 1.0     25035
# Name: c_time_lastob_end, dtype: int64

# %%
cdm=convertPCto10logaritmicscale(cdm)

# %%
cdm.head()
# Out:
#    event_id  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  OBJECT1_CR_R  OBJECT1_CT_R  OBJECT1_CT_T  OBJECT1_CN_R  OBJECT1_CN_T  OBJECT1_CN_N  OBJECT1_CRDOT_R  OBJECT1_CRDOT_T  OBJECT1_CRDOT_N  OBJECT1_CRDOT_RDOT  OBJECT1_CTDOT_R  OBJECT1_CTDOT_T  OBJECT1_CTDOT_N  OBJECT1_CTDOT_RDOT  OBJECT1_CTDOT_TDOT  OBJECT1_CNDOT_R  OBJECT1_CNDOT_T  OBJECT1_CNDOT_N  OBJECT1_CNDOT_RDOT  OBJECT1_CNDOT_TDOT  OBJECT1_CNDOT_NDOT  OBJECT1_RECOMMENDED_OD_SPAN  OBJECT1_ACTUAL_OD_SPAN  OBJECT1_OBS_AVAILABLE  OBJECT1_OBS_USED  OBJECT1_RESIDUALS_ACCEPTED  OBJECT1_WEIGHTED_RMS  OBJECT1_SEDR  OBJECT1_TIME_LASTOB_START  OBJECT1_TIME_LASTOB_END  OBJECT1_CD_AREA_OVER_MASS  OBJECT1_CR_AREA_OVER_MASS  OBJECT1_APOGEE_ALTITUDE  OBJECT1_PERIGEE_ALTITUDE  OBJECT1_INCLINATION  OBJECT2_CR_R  OBJECT2_CT_R  OBJECT2_CT_T  OBJECT2_CN_R  OBJECT2_CN_T  OBJECT2_CN_N  OBJECT2_CRDOT_R  \
#    OBJECT2_CRDOT_T  OBJECT2_CRDOT_N  OBJECT2_CRDOT_RDOT  OBJECT2_CTDOT_R  OBJECT2_CTDOT_T  OBJECT2_CTDOT_N  OBJECT2_CTDOT_RDOT  OBJECT2_CTDOT_TDOT  OBJECT2_CNDOT_R  OBJECT2_CNDOT_T  OBJECT2_CNDOT_N  OBJECT2_CNDOT_RDOT  OBJECT2_CNDOT_TDOT  OBJECT2_CNDOT_NDOT OBJECT2_OBJECT_TYPE  OBJECT2_RECOMMENDED_OD_SPAN  OBJECT2_ACTUAL_OD_SPAN  OBJECT2_OBS_AVAILABLE  OBJECT2_OBS_USED  OBJECT2_RESIDUALS_ACCEPTED  OBJECT2_WEIGHTED_RMS  OBJECT2_SEDR  OBJECT2_TIME_LASTOB_START  OBJECT2_TIME_LASTOB_END  OBJECT2_CD_AREA_OVER_MASS  OBJECT2_CR_AREA_OVER_MASS  OBJECT2_APOGEE_ALTITUDE  OBJECT2_PERIGEE_ALTITUDE  OBJECT2_INCLINATION  __time_to_tca
# 0       -3168066.0         9.684347            3395.637        -32.26525         1974.096        -6.264112           -2.121810            0.027239         25.75459         4131.123         13.00946           -4.434362           -0.042638            0.149353             UNKNOWN                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                      180.0                    180.0                   0.348701                   0.126607               650.497251                606.443389            74.045735       1.566798
# 1       -3134938.0        12.353930            3360.105        -31.40935         1801.103        -6.261605           -1.936377            0.027022         26.23543         4089.899         12.99737           -4.390144           -0.042872            0.149300             UNKNOWN                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                      180.0                    180.0                   0.348701                   0.126607               650.513314                606.454793            74.045736       1.207494
# 2       -3128591.0        12.784440            3353.290        -31.35453         1790.982        -6.261342           -1.925522            0.027012         26.29610         4082.309         12.99521           -4.381993           -0.042886            0.149290             UNKNOWN                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                      180.0                    180.0                   0.348701                   0.126607               650.515082                606.457965            74.045737       0.952193
# 3       -3137905.0        12.848840            3363.293        -31.31480         1782.820        -6.262032           -1.916786            0.026997         26.26511         4093.782         12.99755           -4.394314           -0.042897            0.149305             UNKNOWN                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                      180.0                    180.0                   0.348701                   0.126607               650.515635                606.456229            74.045736       0.579669
# 4       -3132807.0        13.707520            3357.822        -31.12955         1745.518        -6.261718           -1.876801            0.026952         26.36951         4087.192         12.99492           -4.387243           -0.042947            0.149296             UNKNOWN                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                      180.0                    180.0                   0.348701                   0.126607               650.519613                606.459678            74.045736       0.257806

# %%
cdm.shape
# Out:
# (162623, 82)

# %%
cdm.dropna(inplace=True)

# %%
cdm.shape
# Out:
# (153393, 82)

# %%
numeric_cols=cdm.select_dtypes(exclude='number')
cdm.drop(numeric_cols, axis=1, inplace=True)

# %%
cdm.shape
# Out:
# (153393, 81)

# %%
cdm=addCorrelationColumns(cdm)
print("Dataframe size {} x {}".format(cdm.shape[0],cdm.shape[1]))
cdm.head()
# Out:
# Dataframe size 153393 x 111
#    event_id  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  OBJECT1_CR_R  OBJECT1_CT_R  OBJECT1_CT_T  OBJECT1_CN_R  OBJECT1_CN_T  OBJECT1_CN_N  OBJECT1_CRDOT_R  OBJECT1_CRDOT_T  OBJECT1_CRDOT_N  OBJECT1_CRDOT_RDOT  OBJECT1_CTDOT_R  OBJECT1_CTDOT_T  OBJECT1_CTDOT_N  OBJECT1_CTDOT_RDOT  OBJECT1_CTDOT_TDOT  OBJECT1_CNDOT_R  OBJECT1_CNDOT_T  OBJECT1_CNDOT_N  OBJECT1_CNDOT_RDOT  OBJECT1_CNDOT_TDOT  OBJECT1_CNDOT_NDOT  OBJECT1_RECOMMENDED_OD_SPAN  OBJECT1_ACTUAL_OD_SPAN  OBJECT1_OBS_AVAILABLE  OBJECT1_OBS_USED  OBJECT1_RESIDUALS_ACCEPTED  OBJECT1_WEIGHTED_RMS  OBJECT1_SEDR  OBJECT1_TIME_LASTOB_START  OBJECT1_TIME_LASTOB_END  OBJECT1_CD_AREA_OVER_MASS  OBJECT1_CR_AREA_OVER_MASS  OBJECT1_APOGEE_ALTITUDE  OBJECT1_PERIGEE_ALTITUDE  OBJECT1_INCLINATION  OBJECT2_CR_R  OBJECT2_CT_R  OBJECT2_CT_T  OBJECT2_CN_R  OBJECT2_CN_T  OBJECT2_CN_N  OBJECT2_CRDOT_R  \
# 0         0        14923.0         13792.0                453.8               5976.6             -13666.8                 -7.2             -12637.0              -5525.9              -10.204955     16.466810   -222.242200    18938.4700      2.112694     10.002140      3.173451         0.235719       -20.271280        -0.010106            0.021712        -0.016291         0.120850        -0.002307           -0.000127            0.000017         0.002069        -0.000637         0.002828        9.316645e-07           -0.000002            0.000009                         3.78                    3.78                    459               458                        98.9                 1.265      0.000051                        1.0                      1.0                   0.013826                   0.007173               646.745439                590.818294            97.806412      71140.79   -11961160.0  2.955756e+09      5892.756     -6527.382      2172.732         12825.89
# 1         0        14544.0         13792.0                474.3               5821.2             -13319.8                 -7.0             -12637.0              -5525.9              -10.355758     12.438180    -14.462720     3143.8580      1.888744      6.113387      3.243452         0.014658        -3.339774        -0.005643            0.003561        -0.013159        -0.006237        -0.002043            0.000008            0.000014         0.001859         0.000255         0.002964       -9.040335e-07           -0.000002            0.000009                         3.79                    3.79                    456               455                        98.5                 1.270      0.000060                        1.0                      1.0                   0.013487                   0.009139               646.743506                590.823004            97.806420      68744.55   -11602080.0  2.924870e+09      5897.834     -9017.284      2171.175         12440.93
#    OBJECT2_CORR_CRDOT_R  OBJECT2_CORR_CRDOT_T  OBJECT2_CORR_CRDOT_N  OBJECT2_CORR_CTDOT_R  OBJECT2_CORR_CTDOT_T  OBJECT2_CORR_CTDOT_N  OBJECT2_CORR_CTDOT_RDOT  OBJECT2_CORR_CNDOT_R  OBJECT2_CORR_CNDOT_T  OBJECT2_CORR_CNDOT_N  OBJECT2_CORR_CNDOT_RDOT  OBJECT2_CORR_CNDOT_TDOT
# 0              0.825216             -0.999998              0.003565             -0.732954              0.220006             -0.814249                -0.220621              0.249855              0.196620              0.722186                -0.196908                -0.668487
# 1              0.818573             -0.999998              0.004574             -0.728759              0.202595             -0.817490                -0.203216              0.258964              0.195718              0.721903                -0.196008                -0.674979
# 2              0.817774             -0.999998              0.004738             -0.729083              0.201698             -0.817662                -0.202320              0.260092              0.195558              0.721854                -0.195849                -0.675347
# 3              0.817923             -0.999998              0.004755             -0.728092              0.200534             -0.817883                -0.201155              0.259681              0.195808              0.721874                -0.196097                -0.675656
# 4              0.816347             -0.999998              0.005077             -0.727257              0.196662             -0.818575                -0.197284              0.261753              0.195657              0.721794                -0.195947                -0.677041

# %%
#DELETE COVARIANCE MATRIX NON DIAGONAL ELEMENTS
cdm=deleteCovarianceNonDiagonalElements(cdm)
print("Dataframe size {} x {}".format(cdm.shape[0],cdm.shape[1]))
cdm.head()
# Out:
# Dataframe size 153393 x 81
#    event_id  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  OBJECT1_CR_R  OBJECT1_CT_T  OBJECT1_CN_N  OBJECT1_CRDOT_RDOT  OBJECT1_CTDOT_TDOT  OBJECT1_CNDOT_NDOT  OBJECT1_RECOMMENDED_OD_SPAN  OBJECT1_ACTUAL_OD_SPAN  OBJECT1_OBS_AVAILABLE  OBJECT1_OBS_USED  OBJECT1_RESIDUALS_ACCEPTED  OBJECT1_WEIGHTED_RMS  OBJECT1_SEDR  OBJECT1_TIME_LASTOB_START  OBJECT1_TIME_LASTOB_END  OBJECT1_CD_AREA_OVER_MASS  OBJECT1_CR_AREA_OVER_MASS  OBJECT1_APOGEE_ALTITUDE  OBJECT1_PERIGEE_ALTITUDE  OBJECT1_INCLINATION  OBJECT2_CR_R  OBJECT2_CT_T  OBJECT2_CN_N  OBJECT2_CRDOT_RDOT  OBJECT2_CTDOT_TDOT  OBJECT2_CNDOT_NDOT  OBJECT2_RECOMMENDED_OD_SPAN  OBJECT2_ACTUAL_OD_SPAN  OBJECT2_OBS_AVAILABLE  OBJECT2_OBS_USED  OBJECT2_RESIDUALS_ACCEPTED  OBJECT2_WEIGHTED_RMS  OBJECT2_SEDR  OBJECT2_TIME_LASTOB_START  OBJECT2_TIME_LASTOB_END  OBJECT2_CD_AREA_OVER_MASS  OBJECT2_CR_AREA_OVER_MASS  \
_CNDOT_TDOT  OBJECT2_CORR_CT_R  OBJECT2_CORR_CN_R  OBJECT2_CORR_CN_T  OBJECT2_CORR_CRDOT_R  OBJECT2_CORR_CRDOT_T  OBJECT2_CORR_CRDOT_N  OBJECT2_CORR_CTDOT_R  OBJECT2_CORR_CTDOT_T  OBJECT2_CORR_CTDOT_N  OBJECT2_CORR_CTDOT_RDOT  OBJECT2_CORR_CNDOT_R  OBJECT2_CORR_CNDOT_T  OBJECT2_CORR_CNDOT_N  OBJECT2_CORR_CNDOT_RDOT  OBJECT2_CORR_CNDOT_TDOT
# 0               650.497251                606.443389            74.045735       1.566798          -0.397969           0.292258           0.040799              0.394221             -0.999674             -0.038498             -0.981098              0.214612             -0.316493                -0.210247              0.170737             -0.001551              0.531593                 0.002117                -0.179278          -0.824859           0.473976          -0.002576              0.825216             -0.999998              0.003565             -0.732954              0.220006             -0.814249                -0.220621              0.249855              0.196620              0.722186                -0.196908                -0.668487
# 1               650.513314                606.454793            74.045736       1.207494          -0.073137           0.297366           0.060541              0.069652             -0.998192             -0.052511             -0.994240             -0.029644             -0.302333                 0.034030              0.179696              0.001552              0.561142                -0.005165                -0.181036          -0.818207           0.482754          -0.003578              0.818573             -0.999998              0.004574             -0.728759              0.202595             -0.817490                -0.203216              0.258964              0.195718              0.721903                -0.196008                -0.674979
# 2               650.515082                606.457965            74.045737       0.952193          -0.109230           0.305189           0.043711              0.107079             -0.996235             -0.034287             -0.996674              0.033933             -0.308501                -0.030161              0.123760              0.019630              0.579274                -0.023726                -0.125737          -0.817408           0.483828          -0.003742              0.817774             -0.999998              0.004738             -0.729083              0.201698             -0.817662                -0.202320              0.260092              0.195558              0.721854                -0.195849                -0.675347
# 3               650.515635                606.456229            74.045736       0.579669           0.021588           0.423647           0.157544             -0.032072             -0.990913             -0.149998             -0.998856             -0.059398             -0.427166                 0.072214              0.228051              0.039163              0.547564                -0.049976                -0.229497          -0.817557           0.483678          -0.003760              0.817923             -0.999998              0.004755             -0.728092              0.200534             -0.817883                -0.201155              0.259681              0.195808              0.721874                -0.196097                -0.675656
# 4               650.519613                606.459678            74.045736       0.257806           0.417865           0.406002           0.246911             -0.465256             -0.983144             -0.243006             -0.999749             -0.430895             -0.405723                 0.479990              0.223469              0.118674              0.543475                -0.143542                -0.224060          -0.815980           0.485794          -0.004081              0.816347             -0.999998              0.005077             -0.727257              0.196662             -0.818575                -0.197284              0.261753              0.195657              0.721794                -0.195947                -0.677041

# %%
cdm.shape
# Out:
# (153393, 81)

# %%
#DELETE MORE COLUMNS
cdm.drop([     'OBJECT1_TIME_LASTOB_START',
                'OBJECT1_TIME_LASTOB_END',
                'OBJECT2_TIME_LASTOB_START',
                'OBJECT2_TIME_LASTOB_END'
                ], inplace=True, axis=1)

# %% [markdown]
# ## Selecting data to create model
# Because collision event are scarce

# %%
#cdm.COLLISSION_PROBABILITY[0]

# %%
#cdm[cdm["__time_to_tca"]<1]

# %%
#np.log10(0.0001)

# %%
#cdm[cdm["COLLISSION_PROBABILITY"]>np.log10(0.0001)]

# %%
#To create the model i will select only those events that had a CDM with less than 24 hs to conjunction event.
#filtered_data=cdm[cdm["__time_to_tca"]<1]

# %%
nevents=cdm.event_id.nunique()
nevents
# Out:
# 11490

# %%
cdm.head()
# Out:
#    event_id  MISS_DISTANCE  RELATIVE_SPEED  RELATIVE_POSITION_R  RELATIVE_POSITION_T  RELATIVE_POSITION_N  RELATIVE_VELOCITY_R  RELATIVE_VELOCITY_T  RELATIVE_VELOCITY_N  COLLISSION_PROBABILITY  OBJECT1_CR_R  OBJECT1_CT_T  OBJECT1_CN_N  OBJECT1_CRDOT_RDOT  OBJECT1_CTDOT_TDOT  OBJECT1_CNDOT_NDOT  OBJECT1_RECOMMENDED_OD_SPAN  OBJECT1_ACTUAL_OD_SPAN  OBJECT1_OBS_AVAILABLE  OBJECT1_OBS_USED  OBJECT1_RESIDUALS_ACCEPTED  OBJECT1_WEIGHTED_RMS  OBJECT1_SEDR  OBJECT1_CD_AREA_OVER_MASS  OBJECT1_CR_AREA_OVER_MASS  OBJECT1_APOGEE_ALTITUDE  OBJECT1_PERIGEE_ALTITUDE  OBJECT1_INCLINATION  OBJECT2_CR_R  OBJECT2_CT_T  OBJECT2_CN_N  OBJECT2_CRDOT_RDOT  OBJECT2_CTDOT_TDOT  OBJECT2_CNDOT_NDOT  OBJECT2_RECOMMENDED_OD_SPAN  OBJECT2_ACTUAL_OD_SPAN  OBJECT2_OBS_AVAILABLE  OBJECT2_OBS_USED  OBJECT2_RESIDUALS_ACCEPTED  OBJECT2_WEIGHTED_RMS  OBJECT2_SEDR  OBJECT2_CD_AREA_OVER_MASS  OBJECT2_CR_AREA_OVER_MASS  OBJECT2_APOGEE_ALTITUDE  OBJECT2_PERIGEE_ALTITUDE  OBJECT2_INCLINATION  __time_to_tca  \
# 0         0        14923.0         13792.0                453.8               5976.6             -13666.8                 -7.2             -12637.0              -5525.9              -10.204955     16.466810    18938.4700      3.173451            0.021712            0.000017            0.000009                         3.78                    3.78                    459               458                        98.9                 1.265      0.000051                   0.013826                   0.007173               646.745439                590.818294            97.806412      71140.79  2.955756e+09      2172.732            3395.637            0.027239            0.149353                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                   0.348701                   0.126607               650.497251                606.443389            74.045735       1.566798
# 1         0        14544.0         13792.0                474.3               5821.2             -13319.8                 -7.0             -12637.0              -5525.9              -10.355758     12.438180     3143.8580      3.243452            0.003561            0.000014            0.000009                         3.79                    3.79                    456               455                        98.5                 1.270      0.000060                   0.013487                   0.009139               646.743506                590.823004            97.806420      68744.55  2.924870e+09      2171.175            3360.105            0.027022            0.149300                        15.85                   15.85                   15.0              15.0                       100.0                  2.36      0.001406                   0.348701                   0.126607               650.513314                606.454793            74.045736       1.207494
# 1          -0.073137           0.297366           0.060541              0.069652             -0.998192             -0.052511             -0.994240             -0.029644             -0.302333                 0.034030              0.179696              0.001552              0.561142                -0.005165                -0.181036          -0.818207           0.482754          -0.003578              0.818573             -0.999998              0.004574             -0.728759              0.202595             -0.817490                -0.203216              0.258964              0.195718              0.721903                -0.196008                -0.674979
# 2          -0.109230           0.305189           0.043711              0.107079             -0.996235             -0.034287             -0.996674              0.033933             -0.308501                -0.030161              0.123760              0.019630              0.579274                -0.023726                -0.125737          -0.817408           0.483828          -0.003742              0.817774             -0.999998              0.004738             -0.729083              0.201698             -0.817662                -0.202320              0.260092              0.195558              0.721854                -0.195849                -0.675347
# 3           0.021588           0.423647           0.157544             -0.032072             -0.990913             -0.149998             -0.998856             -0.059398             -0.427166                 0.072214              0.228051              0.039163              0.547564                -0.049976                -0.229497          -0.817557           0.483678          -0.003760              0.817923             -0.999998              0.004755             -0.728092              0.200534             -0.817883                -0.201155              0.259681              0.195808              0.721874                -0.196097                -0.675656
# 4           0.417865           0.406002           0.246911             -0.465256             -0.983144             -0.243006             -0.999749             -0.430895             -0.405723                 0.479990              0.223469              0.118674              0.543475                -0.143542                -0.224060          -0.815980           0.485794          -0.004081              0.816347             -0.999998              0.005077             -0.727257              0.196662             -0.818575                -0.197284              0.261753              0.195657              0.721794                -0.195947                -0.677041

# %%
cdm[(cdm["COLLISSION_PROBABILITY"]>-4)& (cdm["__time_to_tca"]<1)].shape
# Out:
# (28, 77)

# %%
cdm[(cdm["COLLISSION_PROBABILITY"]<-4) & (cdm["COLLISSION_PROBABILITY"]>-5)& (cdm["__time_to_tca"]<2)].shape
# Out:
# (260, 77)

# %%
cdm[(cdm["COLLISSION_PROBABILITY"]<-5) & (cdm["COLLISSION_PROBABILITY"]>-6)& (cdm["__time_to_tca"]<2)].shape
# Out:
# (605, 77)

# %%
aux1=cdm[(cdm["COLLISSION_PROBABILITY"]>-4)& (cdm["__time_to_tca"]<1)]
aux2=cdm[(cdm["COLLISSION_PROBABILITY"]<-4) & (cdm["COLLISSION_PROBABILITY"]>-5)& (cdm["__time_to_tca"]<1)]
aux3=cdm[(cdm["COLLISSION_PROBABILITY"]<-5) & (cdm["COLLISSION_PROBABILITY"]>-6)& (cdm["__time_to_tca"]<1)]

# %%
cdm[(cdm["COLLISSION_PROBABILITY"]<-6) & (cdm["COLLISSION_PROBABILITY"]>-7)& (cdm["__time_to_tca"]<1)].shape
# Out:
# (389, 77)

# %%
data.shape

# %%
#data.reset_index(inplace=True)

# %%
data.head()

# %%
# data=pd.read_pickle("full_dataframe_20210908_133957-CORR.pkl")
# data.reset_index(inplace=True)
# data.drop(['index','event_id'], inplace=True, axis=1)
# print(data.shape)
# data.head()

# %%
#Select those events that the time_to_tca at the n-1 CDM is less than one day to conjunction event
filtered_data=data[data["__time_to_tca_4"]<1]

# %%
np.log10(0.000000001)

# %%
data[(data["__time_to_tca_2"]<2) & (data["COLLISSION_PROBABILITY_TARGET"]>-8)].shape

# %%
data[(data["__time_to_tca_2"]<2) & (data["COLLISSION_PROBABILITY_TARGET"]>-8)].shape

# %%
#Choose events that had at least 0.00001 PC of collission
near_collission_events_df=filtered_data[filtered_data["COLLISSION_PROBABILITY_TARGET"]>np.log10(0.00001)]
n_near_collission_events=near_collission_events_df.shape[0]
n_near_collission_events

# %%
subset_no_collision_events=filtered_data[filtered_data["COLLISSION_PROBABILITY_TARGET"]<np.log10(0.00001)].sample(n=n_near_collission_events*2)
subset_no_collision_events.shape

# %%
#data=near_collission_events_df.append(subset_no_collision_events)
data=data[(data["__time_to_tca_4"]<1) & (data["COLLISSION_PROBABILITY_TARGET"]>-8)]

# %%
data=(aux1.append(aux2)).append(aux3)

# %%
data.shape
# Out:
# (322, 77)

# %%
filename="df_{}_ONLY_RISKY_EVENTS-6.pkl".format(dt.datetime.now().strftime("%Y%m%d_%H%M%S"))
print("Saving dataframe for future usage filename = {}".format(filename))
data.to_pickle(filename)
# Out:
# Saving dataframe for future usage filename = df_20210912_003323_ONLY_RISKY_EVENTS-6.pkl

# %%
data.head()

# %% [markdown]
# ## Machine Learning Model

# %%
#import math
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#%matplotlib inline
#import seaborn as sns
#from scipy.stats import norm
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.impute import SimpleImputer



# Bayesian optimization
import warnings
warnings.filterwarnings("ignore")
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score

#import os
#print(os.listdir("../input"))

# %%
#numeric_cols = data.select_dtypes(exclude='number')
#data.drop(numeric_cols, axis=1, inplace=True)

# %%
data.shape

# %%
data.head()

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
train.shape

# %%
test.shape

# %%
train.COLLISSION_PROBABILITY_TARGET

# %%
Y_train = train["COLLISSION_PROBABILITY_TARGET"]
X_train= train.drop(["COLLISSION_PROBABILITY_TARGET"], axis=1)

# %%
Y_test = test["COLLISSION_PROBABILITY_TARGET"]
X_test= test.drop(["COLLISSION_PROBABILITY_TARGET"], axis=1)

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['l2', 'auc'],
    'learning_rate': 0.005,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'verbose': 0,
    "max_depth": 8,
    "num_leaves": 128,  
    "max_bin": 512,
    "num_iterations": 100000,
    "n_estimators": 1000
}

# %%
gbm = lgb.LGBMRegressor(**hyper_params)

# %%
gbm.fit(X_train, Y_train,
        eval_set=[(X_test, Y_test)],
        eval_metric='l1',
        early_stopping_rounds=1000)

# %%
Y_pred = gbm.predict(X_train, num_iteration=gbm.best_iteration_)

# %%
type(Y_pred)

# %%
print('The rmse of prediction is:', round(mean_squared_log_error(-Y_pred, -Y_train) ** 0.5, 5))

# %% [markdown]
# ## Bayesian Optimization

# %% [markdown]
# ### Step 1: Parameters to be tuned

# %%
""" def lgb_eval(num_leaves, feature_fraction, bagging_fraction, max_depth, lambda_l1, lambda_l2, min_split_gain, min_child_weight):
    params = {'application':'binary','num_iterations':4000, 'learning_rate':0.05, 'early_stopping_round':100, 'metric':'auc'}
    params["num_leaves"] = round(num_leaves)
    params['feature_fraction'] = max(min(feature_fraction, 1), 0)
    params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
    params['max_depth'] = round(max_depth)
    params['lambda_l1'] = max(lambda_l1, 0)
    params['lambda_l2'] = max(lambda_l2, 0)
    params['min_split_gain'] = min_split_gain
    params['min_child_weight'] = min_child_weight
    cv_result = lgb.cv(params, train_data, nfold=n_folds, seed=random_seed, stratified=True, verbose_eval =200, metrics=['auc'])
    return max(cv_result['auc-mean']) """

# %% [markdown]
# ### Step 2: Set the range for each parameter

# %%
# lgbBO = BayesianOptimization(lgb_eval, {'num_leaves': (24, 45),
#                                         'feature_fraction': (0.1, 0.9),
#                                         'bagging_fraction': (0.8, 1),
#                                         'max_depth': (5, 8.99),
#                                         'lambda_l1': (0, 5),
#                                         'lambda_l2': (0, 3),
#                                         'min_split_gain': (0.001, 0.1),
#                                         'min_child_weight': (5, 50)}, random_state=0)

# %% [markdown]
# ### Step 3: Bayesian Optimization: Maximize

# %%
#lgbBO.maximize(init_points=init_round, n_iter=opt_round)

# %% [markdown]
# ### Step 4: Get the parameters

# %%
#lgbBO.res['max']['max_params']

# %% [markdown]
# ### All together

# %%
X = X_train
y = Y_train
def bayes_parameter_opt_lgb(X, y, init_round=15, opt_round=25, n_folds=5, random_seed=6, n_estimators=10000, learning_rate=0.05, output_process=False):
    # prepare data
    train_data = lgb.Dataset(data=X, label=y, free_raw_data=False)
    # parameters
    def lgb_eval(num_leaves, feature_fraction, bagging_fraction, max_depth, lambda_l1, lambda_l2, min_split_gain, min_child_weight):
        params = {'application':'binary','num_iterations': n_estimators, 'learning_rate':learning_rate, 'early_stopping_round':100, 'metric':'auc'}
        params["num_leaves"] = int(round(num_leaves))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
        params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
        params['max_depth'] = int(round(max_depth))
        params['lambda_l1'] = max(lambda_l1, 0)
        params['lambda_l2'] = max(lambda_l2, 0)
        params['min_split_gain'] = min_split_gain
        params['min_child_weight'] = min_child_weight
        cv_result = lgb.cv(params, train_data, nfold=n_folds, seed=random_seed, stratified=True, verbose_eval =200, metrics=['auc'])
        return max(cv_result['auc-mean'])
    # range 
    lgbBO = BayesianOptimization(lgb_eval, {'num_leaves': (24, 45),
                                            'feature_fraction': (0.1, 0.9),
                                            'bagging_fraction': (0.8, 1),
                                            'max_depth': (5, 8.99),
                                            'lambda_l1': (0, 5),
                                            'lambda_l2': (0, 3),
                                            'min_split_gain': (0.001, 0.1),
                                            'min_child_weight': (5, 50)}, random_state=0)
    # optimize
    lgbBO.maximize(init_points=init_round, n_iter=opt_round)
    
    # output optimization process
    if output_process==True: lgbBO.points_to_csv("bayes_opt_result.csv")
    
    # return best parameters
    return lgbBO.res['max']['max_params']

opt_params = bayes_parameter_opt_lgb(X, y, init_round=5, opt_round=10, n_folds=3, random_seed=6, n_estimators=100, learning_rate=0.05)

# %%
print(opt_params)
